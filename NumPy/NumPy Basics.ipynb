# %% [markdown]
#  # NumPy Basics: Arrays and Vectorized Computation

# %%
import numpy as np

# %%
my_arr = np.arange(1000000)

# %%
my_list = list(range(1000000))

# %%
 # %time for _ in range(10): my_arr2 = my_arr * 2
# Out:
# CPU times: total: 31.2 ms
# Wall time: 27.2 ms

# %%
# %time for _ in range(10): my_list2 = [x * 2 for x in my_list]
# Out:
# CPU times: total: 453 ms
# Wall time: 469 ms

# %%
data = np.random.randn(2,3)

# %%
data
# Out:
# array([[-1.35619092, -0.08718592,  0.18504922],
#        [-2.76485038, -1.23515539, -1.8838491 ]])

# %%
data *10
# Out:
# array([[-13.56190921,  -0.87185917,   1.85049219],
#        [-27.64850375, -12.35155386, -18.83849099]])

# %%
data + data
# Out:
# array([[-2.71238184, -0.17437183,  0.37009844],
#        [-5.52970075, -2.47031077, -3.7676982 ]])

# %%
data.shape
# Out:
# (2, 3)
