# %% [markdown]
# # NumPy Basics.

# %%
import numpy as np

# %%
my_arr = np.arange(1000000)

# %%
my_list = list (range(1000000))

# %%
# %time for _ in range(10): my_arr2 = my_arr*2
# Out:
# CPU times: total: 31.2 ms
# Wall time: 25.9 ms

# %%
# %time for _ in range(10): my_list2 = [x * 2 for x in  my_list]
# Out:
# CPU times: total: 484 ms
# Wall time: 487 ms

# %% [markdown]
# ## The NumPy ndarry : A Multidimensional Array Object

# %%
# Generate some random data 
data = np.random .randn(2, 3)

# %%
data
# Out:
# array([[ 1.10721891, -0.43735946, -0.45039787],
#        [ 1.2328963 ,  0.52526323, -1.72265576]])

# %%
data * 10
# Out:
# array([[ 11.07218908,  -4.37359464,  -4.5039787 ],
#        [ 12.32896302,   5.25263226, -17.22655761]])

# %%
data + data
# Out:
# array([[ 2.21443782, -0.87471893, -0.90079574],
#        [ 2.4657926 ,  1.05052645, -3.44531152]])

# %%
# shape

# %%
data.shape
# Out:
# (2, 3)

# %%
data.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Creating ndarrays

# %%
data1 = [6,7.5,8,0,1]

# %%
arr1 = np.array(data1)

# %%
arr1
# Out:
# array([6. , 7.5, 8. , 0. , 1. ])

# %%
data2 = [[1,2,3,4], [5,6,7,8]]

# %%
arr2 = np.array(data2)

# %%
arr2
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
arr2.ndim
# Out:
# 2

# %%
arr2.shape
# Out:
# (2, 4)
